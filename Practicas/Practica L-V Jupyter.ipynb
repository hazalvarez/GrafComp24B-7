# %% [markdown]
# ### LIBRERIAS

# %%
import matplotlib.pyplot as plt
from random import *
from numpy import *
import sys
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# #### CÓDIGO ORIGINAL

# %%
a = 0.7; b = 0.5; c = 0.3; e = 0.2
dt = 0.001; max_time = 100
t = 0; x = 1.0; y = 0.5
t_list = []; x_list = []; y_list = []
t_list.append(t); x_list.append(x); y_list.append(y)
while t < max_time:
    t = t + dt
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

p = plt.plot(t_list, x_list, 'r', t_list, y_list, 'g', linewidth = 2)

# %% [markdown]
# En el anterior gráfico podemos observar que el aumento de la presencia de las presas
# es mayor que el de los depredadores dado que el aumento natural de las presas es de
# (0.7) y la destrucción por depredador es de (0.5), con ello podemos ver que se
# reproducen más rápido las presas que la muerte por depredador, al igual vemos que
# la muerte de los depredadores es mayor con (0.3) que el aumento de los mismo por
# alimento de las presas con (0.2)

# %% [markdown]
# ### ESCENARIO 1

# %%
a = 0.5; b = 0.6; c = 0.3; e = 0.5
dt = 0.001; max_time = 100
t = 0; x = 1.0; y = 0.5
t_list = []; x_list = []; y_list = []
t_list.append(t); x_list.append(x); y_list.append(y)
while t < max_time:
    
    t = t + dt
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

p = plt.plot(t_list, x_list, 'r', t_list, y_list, 'g', linewidth = 2)

# %% [markdown]
# En el anterior escenario podemos ver que el numero de depredadores es mayor que
# el numero de presas dado que la muerte de las presas (0.6) es mayor que la presencia
# natural de las presas (0.5), y el aumento de los depredadores (0.5) es mayor que la
# muerte de estos por falta de presas (0.3).

# %% [markdown]
# ### ESCENARIO 2

# %%
a = 0.3; b = 0; c = 1.0; e = 0
dt = 0.001; max_time = 100
t = 0; x = 1.0; y = 0.5
t_list = []; x_list = []; y_list = []
t_list.append(t); x_list.append(x); y_list.append(y)
while t < max_time:
    t = t + dt
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

p = plt.plot(t_list, x_list, 'r', t_list, y_list, 'g', linewidth = 2)

# %% [markdown]
# En el escenario anterior podemos ver como hay un crecimiento incontrolable de las
# presas y ninguno por parte de los depredadores dado que la presencia de las presas
# aumenta (0.3) y nunca disminuye ya que no existe un crecimiento de los
# depredadores.

# %% [markdown]
# ### ESCENARIO 3

# %%
a = 0.3; b = 0.3; c = 0; e = 0.2
dt = 0.001; max_time = 100
t = 0; x = 1.0; y = 0.5
t_list = []; x_list = []; y_list = []
t_list.append(t); x_list.append(x); y_list.append(y)
while t < max_time:
    t = t + dt
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

p = plt.plot(t_list, x_list, 'r', t_list, y_list, 'g', linewidth = 2)

# %% [markdown]
# En el escenario anterior podemos ver que la población de las presas aumenta, pero
# llega un punto donde los depredadores aumentan descontroladamente que las
# presas no son suficientes para seguir aumentando su crecimiento, dado que los
# depredadores no tienen una muerte por ausencia de las presas.

# %% [markdown]
# ### ESCENARIO 4

# %%
a = 0; b = 0; c = 0; e = 0
dt = 0.001; max_time = 100
t = 0; x = 1.0; y = 0.5
t_list = []; x_list = []; y_list = []
t_list.append(t); x_list.append(x); y_list.append(y)
while t < max_time:
    t = t + dt
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

p = plt.plot(t_list, x_list, 'r', t_list, y_list, 'g', linewidth = 2)

# %% [markdown]
# En el escenario anterior podemos ver que no existe ni presas ni depredadores, por lo
# tanto, podemos ver en el grafico la ausencia de ambas poblaciones

# %% [markdown]
# ### ESCENARIO 5

# %%
a = 0.8; b = 0.1; c = 0.5; e = 0.1
dt = 0.001; max_time = 100
t = 0; x = 1.0; y = 0.5
t_list = []; x_list = []; y_list = []
t_list.append(t); x_list.append(x); y_list.append(y)
while t < max_time:
    t = t + dt
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

p = plt.plot(t_list, x_list, 'r', t_list, y_list, 'g', linewidth = 2)

# %% [markdown]
# En el ultimo escenario podemos ver un aumento de ambas poblaciones, pero llega un
# punto en el que los depredadores empiezan a alimentarse demasiado que las presas
# empiezan a morir rápidamente y a su vez los depredadores por falta de alimento, de
# igual forma podemos ver que los depredadores llegan hacer una población más
# grande que la población de las presas.
