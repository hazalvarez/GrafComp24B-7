# %% [markdown]
# ##Christopher Octavio tellez Dominguez
#
# A continuación se realiza el siguiente poligono formado por varios vectores![poligono.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.arrow(0,0,4,3, color=("green"))
plt.arrow(4,3,-.1,2, color=("red"))
plt.arrow(3.9,5,3,-4, color=("blue"))
plt.arrow(6.9,1,-3.5,-1, color=("yellow"))
plt.arrow(3.4,0,-3,-3, color=("green"))
plt.arrow(.4,-3,-4,-.5, color=("red"))
plt.arrow(-3.6,-3.5,-3,3, color=("blue"))
plt.arrow(-6.6,-.5,.5,4, color=("yellow"))
plt.arrow(-6.1,3.5,3,-2, color=("green"))
plt.arrow(-3.1,1.5,1,1, color=("red"))
plt.arrow(-2.1,2.5,-1.5,1.5, color=("blue"))
plt.arrow(-3.6,4,.5,2, color=("yellow"))
plt.arrow(-3.1,6,4,-1, color=("green"))
plt.arrow(.9,5,-.5,-1.2, color=("red"))
plt.arrow(.4,3.8,-2,-2.5, color=("blue"))
plt.arrow(-1.6,1.3,1.6,-1.3, color=("yellow"))


plt.xlim(0,4)
plt.ylim(0,8)


plt.xlim(-8,8)
plt.ylim(-8,8)

plt.axvline(x=0)
plt.axhline(y=0)

plt.grid(True)
plt.axis("on")

plt.show()
